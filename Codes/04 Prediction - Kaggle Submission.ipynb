# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import statsmodels.api as sm
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso, LassoCV
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV


plt.figure(figsize = (12,9))
sns.set_theme(style="ticks")
sns.set_palette("Set1", 8, .75)
sns.set_context("talk", rc={"lines.linewidth": 2})

# %% [markdown]
# Let's load the cleaned test data.

# %%
feature1_train = pd.read_csv('./datasets/df_train_cleaned.csv')
feature1_test = pd.read_csv('./datasets/df_test_cleaned.csv')

# %%
feature1_train.shape
# Out:
# (2038, 47)

# %%
feature1_test.shape
# Out:
# (878, 47)

# %%
feature1_train.describe()
# Out:
#        ms_subclass  lot_frontage       lot_area    lot_shape    utilities  \
# count  2038.000000   2038.000000    2038.000000  2038.000000  2038.000000
# mean     57.127085     68.963796    9992.582434     3.599117     3.998528
# std      42.905372     21.261635    6615.808437     0.564660     0.049522
# min      20.000000     21.000000    1300.000000     1.000000     2.000000
# 25%      20.000000     60.000000    7500.000000     3.000000     4.000000
# 50%      50.000000     69.055200    9378.500000     4.000000     4.000000
# 75%      70.000000     78.000000   11452.750000     4.000000     4.000000
# max     190.000000    313.000000  159000.000000     4.000000     4.000000
#
#        neighborhood  overall_qual  overall_cond  year_remod/add  mas_vnr_area  \
# count   2038.000000   2038.000000   2038.000000     2038.000000   2038.000000
# mean       2.439647      6.091757      5.565751     1984.052993     96.120859
# std        0.921056      1.406877      1.107100       21.030500    167.535680
# min        1.000000      1.000000      1.000000     1950.000000      0.000000
# 25%        2.000000      5.000000      5.000000     1964.000000      0.000000
# 50%        2.000000      6.000000      5.000000     1993.000000      0.000000
# 75%        3.000000      7.000000      6.000000     2004.000000    150.000000
# max        4.000000     10.000000      9.000000     2010.000000   1600.000000
#
#        ...  bldg_type_1Fam  bldg_type_2fmCon  bldg_type_Duplex  \
# count  ...     2038.000000       2038.000000       2038.000000
# mean   ...        0.827772          0.022571          0.036801
# std    ...        0.377671          0.148568          0.188319
# min    ...        0.000000          0.000000          0.000000
# 25%    ...        1.000000          0.000000          0.000000
# 50%    ...        1.000000          0.000000          0.000000
# 75%    ...        1.000000          0.000000          0.000000
# max    ...        1.000000          1.000000          1.000000
#
#        bldg_type_Twnhs  bldg_type_TwnhsE  exterior_3rd  bsmt_qual_cond_merged  \
# count      2038.000000       2038.000000   2038.000000            2038.000000
# mean          0.033857          0.078999      2.752699               6.409715
# std           0.180905          0.269803      1.049899               1.337295
# min           0.000000          0.000000      0.000000               0.000000
# 25%           0.000000          0.000000      2.000000               6.000000
# 50%           0.000000          0.000000      2.000000               7.000000
# 75%           0.000000          0.000000      4.000000               7.000000
# max           1.000000          1.000000      4.000000               9.000000
#
#        bsmtfin_type_merged  bsmtfin_sf_merged  garage_qual_cond_merged
# count          2038.000000        2038.000000              2038.000000
# mean              4.827772         484.682532                 5.610402
# std               2.418281         474.843706                 1.423324
# min               0.000000           0.000000                 0.000000
# 25%               2.000000           0.000000                 6.000000
# 50%               5.000000         453.000000                 6.000000
# 75%               7.000000         788.750000                 6.000000
# max              11.000000        5644.000000                10.000000
#
# [8 rows x 47 columns]

# %%
feature1_test.describe()
# Out:
#                 id  ms_subclass  lot_frontage       lot_area   lot_shape  \
# count   878.000000   878.000000    878.000000     878.000000  878.000000
# mean   1444.749431    58.268793     69.545961   10307.033030    3.602506
# std     850.838263    42.235407     21.279162   10002.674602    0.579264
# min       2.000000    20.000000     21.000000    1477.000000    1.000000
# 25%     692.250000    20.000000     60.000000    7297.250000    3.000000
# 50%    1433.000000    50.000000     69.545961    9446.000000    4.000000
# 75%    2197.500000    70.000000     78.000000   11589.000000    4.000000
# max    2928.000000   190.000000    182.000000  215245.000000    4.000000
#
#         utilities  neighborhood  overall_qual  overall_cond  year_remod/add  \
# count  878.000000    878.000000    878.000000    878.000000      878.000000
# mean     3.998861      2.451025      6.050114      5.566059     1984.417995
# std      0.033748      0.925623      1.369065      1.128903       20.450725
# min      3.000000      1.000000      2.000000      1.000000     1950.000000
# 25%      4.000000      2.000000      5.000000      5.000000     1967.000000
# 50%      4.000000      3.000000      6.000000      5.000000     1992.000000
# 75%      4.000000      3.000000      7.000000      6.000000     2003.000000
# max      4.000000      4.000000     10.000000      9.000000     2010.000000
#
#        ...  bldg_type_1Fam  bldg_type_2fmCon  bldg_type_Duplex  \
# count  ...      878.000000        878.000000        878.000000
# mean   ...        0.824601          0.018223          0.038724
# std    ...        0.380524          0.133834          0.193047
# min    ...        0.000000          0.000000          0.000000
# 25%    ...        1.000000          0.000000          0.000000
# 50%    ...        1.000000          0.000000          0.000000
# 75%    ...        1.000000          0.000000          0.000000
# max    ...        1.000000          1.000000          1.000000
#
#        bldg_type_Twnhs  bldg_type_TwnhsE  exterior_3rd  bsmt_qual_cond_merged  \
# count       878.000000        878.000000    878.000000             878.000000
# mean          0.036446          0.082005      2.719818               6.358770
# std           0.187505          0.274528      1.044656               1.347318
# min           0.000000          0.000000      0.000000               0.000000
# 25%           0.000000          0.000000      2.000000               6.000000
# 50%           0.000000          0.000000      2.000000               6.000000
# 75%           0.000000          0.000000      4.000000               7.000000
# max           1.000000          1.000000      4.000000               9.000000
#
#        bsmtfin_type_merged  bsmtfin_sf_merged  garage_qual_cond_merged
# count           878.000000         878.000000               878.000000
# mean              4.785877         495.224374                 5.605923
# std               2.380974         463.012119                 1.378136
# min               0.000000           0.000000                 0.000000
# 25%               2.000000           0.000000                 6.000000
# 50%               5.000000         474.000000                 6.000000
# 75%               7.000000         822.000000                 6.000000
# max              11.000000        2288.000000                 9.000000
#
# [8 rows x 47 columns]

# %%
x_train = feature1_train.drop(columns =['saleprice'])
y_train = feature1_train['saleprice']
x_test = feature1_test

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
# Out:
# (2038, 46)
# (2038,)
# (878, 47)

# %%
x_train = sm.add_constant(x_train)

# %%
sc = StandardScaler()
z_train = sc.fit_transform(x_train)
z_test = sc.transform(x_test)

# %%
r_alphas = np.logspace(0,5,100)

# %%
ridge_cv = RidgeCV(alphas=r_alphas, scoring='r2', cv=5)

# %%
ridge_cv.fit(z_train, y_train)
# Out:
# RidgeCV(alphas=array([1.00000000e+00, 1.12332403e+00, 1.26185688e+00, 1.41747416e+00,
#        1.59228279e+00, 1.78864953e+00, 2.00923300e+00, 2.25701972e+00,
#        2.53536449e+00, 2.84803587e+00, 3.19926714e+00, 3.59381366e+00,
#        4.03701726e+00, 4.53487851e+00, 5.09413801e+00, 5.72236766e+00,
#        6.42807312e+00, 7.22080902e+00, 8.11130831e+00, 9.11162756e+00,
#        1.02353102e+01, 1.14975700e+0...
#        6.89261210e+03, 7.74263683e+03, 8.69749003e+03, 9.77009957e+03,
#        1.09749877e+04, 1.23284674e+04, 1.38488637e+04, 1.55567614e+04,
#        1.74752840e+04, 1.96304065e+04, 2.20513074e+04, 2.47707636e+04,
#        2.78255940e+04, 3.12571585e+04, 3.51119173e+04, 3.94420606e+04,
#        4.43062146e+04, 4.97702356e+04, 5.59081018e+04, 6.28029144e+04,
#        7.05480231e+04, 7.92482898e+04, 8.90215085e+04, 1.00000000e+05]),
#         cv=5, scoring='r2')

# %%
ridge_predict = ridge_cv.predict(z_train)

# %%
ridge_predict_test = ridge_cv.predict(z_test)

# %%
feature1_test['saleprice'] = ridge_predict_test

# %%
feature1_test
# Out:
#        id  ms_subclass  lot_frontage  lot_area  lot_shape  utilities  \
# 0    2658          190     69.000000      9142          4          4
# 1    2718           90     69.545961      9662          3          4
# 2    2414           60     58.000000     17104          3          4
# 3    1989           30     60.000000      8520          4          4
# 4     625           20     69.545961      9500          3          4
# ..    ...          ...           ...       ...        ...        ...
# 873  1662           60     80.000000      8000          4          4
# 874  1234           60     90.000000     14670          4          4
# 875  1373           20     55.000000      8250          4          4
# 876  1672           20     60.000000      9000          4          4
# 877  1939           20     70.000000      8400          4          4
#
#      neighborhood  overall_qual  overall_cond  year_remod/add  ...  \
# 0               1             6             8            1950  ...
# 1               2             5             4            1977  ...
# 2               3             7             5            2006  ...
# 3               1             5             6            2006  ...
# 4               2             6             5            1963  ...
# ..            ...           ...           ...             ...  ...
# 873             3             6             6            1974  ...
# 874             2             6             7            1999  ...
# 875             2             5             5            1968  ...
# 876             2             4             6            1971  ...
# 877             2             5             5            1955  ...
#
#      bldg_type_2fmCon  bldg_type_Duplex  bldg_type_Twnhs  bldg_type_TwnhsE  \
# 0                   1                 0                0                 0
# 1                   0                 1                0                 0
# 2                   0                 0                0                 0
# 3                   0                 0                0                 0
# 4                   0                 0                0                 0
# ..                ...               ...              ...               ...
# 873                 0                 0                0                 0
# 874                 0                 0                0                 0
# 875                 0                 0                0                 0
# 876                 0                 0                0                 0
# 877                 0                 0                0                 0
#
#      exterior_3rd  bsmt_qual_cond_merged  bsmtfin_type_merged  \
# 0               0                      5                    2
# 1               2                      7                    2
# 2               4                      8                    7
# 3               2                      6                    2
# 4               2                      7                    5
# ..            ...                    ...                  ...
# 873             2                      6                    7
# 874             4                      6                    5
# 875             2                      6                    6
# 876             2                      6                    6
# 877             2                      6                    5
#
#      bsmtfin_sf_merged  garage_qual_cond_merged      saleprice
# 0                    0                        2  131444.662057
# 1                    0                        6  144703.071442
# 2                  554                        6  230631.927656
# 3                    0                        5  118261.715155
# 4                  609                        6  178201.903247
# ..                 ...                      ...            ...
# 873               1084                        6  200611.569243
# 874                575                        6  227097.682724
# 875                742                        6  131082.812506
# 876                616                        6  107544.231695
# 877                793                        6  125972.835732
#
# [878 rows x 48 columns]

# %%
ridge_submission = feature1_test[['id','saleprice']]

# %%
ridge_submission
# Out:
#        id      saleprice
# 0    2658  131444.662057
# 1    2718  144703.071442
# 2    2414  230631.927656
# 3    1989  118261.715155
# 4     625  178201.903247
# ..    ...            ...
# 873  1662  200611.569243
# 874  1234  227097.682724
# 875  1373  131082.812506
# 876  1672  107544.231695
# 877  1939  125972.835732
#
# [878 rows x 2 columns]
